# %%
from mypulp import *
import numpy as np
import itertools
import networkx as nx
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 制約付き最短路問題 (CSP)

# %%
# CSPを解いた結果を返す関数
def solve_CSP(V, E, u):
    model = Model('csp')
    
    ## 変数
    x = {}
    for i, j in E:
        x[i, j] = model.addVar(vtype='B', name=f'x_{i},{j}')
    model.update()
    
    ## 定式化
    ### 制約式
    model.addConstr(quicksum(c[i, j] * x[i, j] for i, j in E) <= u)
    
    for i in V[1: -1]:
        delta_p = [(i_, j) for i_, j in E if i_==i]  # ノードiから出る枝の集合
        delta_m = [(j, i_) for j, i_ in E if i_==i]  # ノードiに入る枝の集合
        model.addConstr(quicksum(x[i_, j] for i_, j in delta_p)
                        - quicksum(x[i_, j] for i_, j in delta_m) == 0)
                        
    model.addConstr(quicksum(x[i, j] for i, j in E if i==V[0]) == 1)
    model.addConstr(quicksum(x[i, j] for i, j in E if j==V[-1]) == 1)
 
    ### 目的関数
    model.setObjective(quicksum(l[i, j] * x[i, j] for i, j in E), GRB.MINIMIZE)
    
    model.update()
    model.__data = x
    
    return model

# %%
# 例題
V = range(4)
E = [(0, 1), (0, 2), (1, 2), (1, 3), (2, 3)]
c = {(0, 1): 0, (0, 2): 2, (1, 2): 9, (1, 3): 9, (2, 3): 5}
l = {(0, 1): 2, (0, 2): 6, (1, 2): 1, (1, 3): 5, (2, 3): 3}
u = 10

# %%
# 最適化
model = solve_CSP(V, E, u)
model.optimize()
print(f'Optimal Value: {model.ObjVal}')

x = model.__data
eps = 1.0e-6
optsol = []
for i, j in x:
    if x[i, j].X > eps:
        optsol.append(x[i, j])

print(f'Optimal Solution: {optsol}')
# Out:
# Optimal Value: 7.0
# Optimal Solution: [x_0,1, x_1,3]

# %% [markdown]
# ## CSPの不等式制約に対するラグランジュ緩和問題 (LSP)

# %%
# CSPを解いた結果を返す関数
def solve_LSP(V, E, u, sigma):
    model = Model('lsp')
    
    ## 変数
    x = {}
    for i, j in E:
        x[i, j] = model.addVar(vtype='B', name=f'x_{i},{j}')
    model.update()
    
    ## 定式化
    ### 制約式
    for i in V[1: -1]:
        delta_p = [(i_, j) for i_, j in E if i_==i]  # ノードiから出る枝の集合
        delta_m = [(j, i_) for j, i_ in E if i_==i]  # ノードiに入る枝の集合
        model.addConstr(quicksum(x[i_, j] for i_, j in delta_p)
                        - quicksum(x[i_, j] for i_, j in delta_m) == 0)
                        
    model.addConstr(quicksum(x[i, j] for i, j in E if i==V[0]) == 1)
    model.addConstr(quicksum(x[i, j] for i, j in E if j==V[-1]) == 1)
 
    ### 目的関数
    model.setObjective(quicksum(l[i, j] * x[i, j] for i, j in E)
                       + sigma*(quicksum(c[i, j] * x[i, j] for i, j in E) - u), GRB.MINIMIZE)
    
    model.update()
    model.__data = x
    
    return model

# %%
# 最適化
model = solve_LSP(V, E, u, sigma=0.2)  # 最強ラグランジュ乗数
model.optimize()
print(f'Optimal Value: {model.ObjVal}')

x = model.__data
eps = 1.0e-6
optsol = []
for i, j in x:
    if x[i, j].X > eps:
        optsol.append(x[i, j])

print(f'Optimal Solution: {optsol}')
# Out:
# Optimal Value: 6.8
# Optimal Solution: [x_0,1, x_1,2, x_2,3]

# %% [markdown]
# 最強ラグランジュ乗数を劣勾配法を用いて探索する

# %%
sigma = 0
count = 1
eps = 1.0e-2
converge = False

while not converge:
    # LSPを解く
    model = solve_LSP(V, E, u, sigma=sigma)
    model.optimize()
    x = model.__data
    
    # sigmaの係数（=劣勾配）
    sub_grad = value(quicksum(c[i, j] * x[i, j].X for i, j in E) - u)
    
    # ちゃんと収束するようにsigmaの更新幅は徐々に小さくしていく
    # sigmaの更新幅が微小定数epsよりも小さくなれば終了する
    if np.abs(sub_grad / count) < eps:
        converge = True
        count += 1
    else:
        sigma = np.max([0, sigma + sub_grad/count])
        count += 1

    print(f'{count-1}回目の反複：sigma={sigma: .4f}, Objval={model.ObjVal: .4f}')
# Out:
# 1回目の反複：sigma= 4.0000, Objval= 6.0000
# 2回目の反複：sigma= 2.5000, Objval=-3.0000
# 3回目の反複：sigma= 1.5000, Objval= 1.5000
# 4回目の反複：sigma= 0.7500, Objval= 4.5000
# 5回目の反複：sigma= 0.5500, Objval= 6.2500
# 6回目の反複：sigma= 0.3833, Objval= 6.4500
# 7回目の反複：sigma= 0.2405, Objval= 6.6167
# 8回目の反複：sigma= 0.1155, Objval= 6.7595
# 9回目の反複：sigma= 0.5599, Objval= 6.4619
# 10回目の反複：sigma= 0.4599, Objval= 6.4401
# 11回目の反複：sigma= 0.3690, Objval= 6.5401
# 12回目の反複：sigma= 0.2857, Objval= 6.6310
# 13回目の反複：sigma= 0.2088, Objval= 6.7143
# 14回目の反複：sigma= 0.1373, Objval= 6.7912
# 15回目の反複：sigma= 0.4040, Objval= 6.5493
# 16回目の反複：sigma= 0.3415, Objval= 6.5960
# 17回目の反複：sigma= 0.2827, Objval= 6.6585
# 18回目の反複：sigma= 0.2271, Objval= 6.7173
# 19回目の反複：sigma= 0.1745, Objval= 6.7729
# 20回目の反複：sigma= 0.3745, Objval= 6.6979
# 21回目の反複：sigma= 0.3269, Objval= 6.6255
# 22回目の反複：sigma= 0.2814, Objval= 6.6731
# 23回目の反複：sigma= 0.2379, Objval= 6.7186
# 24回目の反複：sigma= 0.1963, Objval= 6.7621
# 25回目の反複：sigma= 0.3563, Objval= 6.7851
# 26回目の反複：sigma= 0.3178, Objval= 6.6437
# 27回目の反複：sigma= 0.2808, Objval= 6.6822
# 28回目の反複：sigma= 0.2451, Objval= 6.7192
# 29回目の反複：sigma= 0.2106, Objval= 6.7549
# 30回目の反複：sigma= 0.1772, Objval= 6.7894
# 31回目の反複：sigma= 0.3063, Objval= 6.7089
# 32回目の反複：sigma= 0.2750, Objval= 6.6937
# 33回目の反複：sigma= 0.2447, Objval= 6.7250
# 34回目の反複：sigma= 0.2153, Objval= 6.7553
# 35回目の反複：sigma= 0.1867, Objval= 6.7847
# 36回目の反複：sigma= 0.2978, Objval= 6.7469
# 37回目の反複：sigma= 0.2708, Objval= 6.7022
# 38回目の反複：sigma= 0.2445, Objval= 6.7292
# 39回目の反複：sigma= 0.2189, Objval= 6.7555
# 40回目の反複：sigma= 0.1939, Objval= 6.7811
# 41回目の反複：sigma= 0.2914, Objval= 6.7754
# 42回目の反複：sigma= 0.2676, Objval= 6.7086
# 43回目の反複：sigma= 0.2444, Objval= 6.7324
# 44回目の反複：sigma= 0.2216, Objval= 6.7556
# 45回目の反複：sigma= 0.1994, Objval= 6.7784
# 46回目の反複：sigma= 0.2864, Objval= 6.7976
# 47回目の反複：sigma= 0.2651, Objval= 6.7136
# 48回目の反複：sigma= 0.2443, Objval= 6.7349
# 49回目の反複：sigma= 0.2238, Objval= 6.7557
# 50回目の反複：sigma= 0.2038, Objval= 6.7762
# 51回目の反複：sigma= 0.1842, Objval= 6.7962
# 52回目の反複：sigma= 0.2612, Objval= 6.7369
# 53回目の反複：sigma= 0.2423, Objval= 6.7388
# 54回目の反複：sigma= 0.2238, Objval= 6.7577
# 55回目の反複：sigma= 0.2056, Objval= 6.7762
# 56回目の反複：sigma= 0.1877, Objval= 6.7944
# 57回目の反複：sigma= 0.2579, Objval= 6.7509
# 58回目の反複：sigma= 0.2407, Objval= 6.7421
# 59回目の反複：sigma= 0.2237, Objval= 6.7593
# 60回目の反複：sigma= 0.2071, Objval= 6.7763
# 61回目の反複：sigma= 0.1907, Objval= 6.7929
# 62回目の反複：sigma= 0.2552, Objval= 6.7626
# 63回目の反複：sigma= 0.2393, Objval= 6.7448
# 64回目の反複：sigma= 0.2237, Objval= 6.7607
# 65回目の反複：sigma= 0.2083, Objval= 6.7763
# 66回目の反複：sigma= 0.1931, Objval= 6.7917
# 67回目の反複：sigma= 0.2528, Objval= 6.7726
# 68回目の反複：sigma= 0.2381, Objval= 6.7472
# 69回目の反複：sigma= 0.2236, Objval= 6.7619
# 70回目の反複：sigma= 0.2094, Objval= 6.7764
# 71回目の反複：sigma= 0.1953, Objval= 6.7906
# 72回目の反複：sigma= 0.2508, Objval= 6.7811
# 73回目の反複：sigma= 0.2371, Objval= 6.7492
# 74回目の反複：sigma= 0.2236, Objval= 6.7629
# 75回目の反複：sigma= 0.2103, Objval= 6.7764
# 76回目の反複：sigma= 0.1971, Objval= 6.7897
# 77回目の反複：sigma= 0.2491, Objval= 6.7885
# 78回目の反複：sigma= 0.2363, Objval= 6.7509
# 79回目の反複：sigma= 0.2236, Objval= 6.7637
# 80回目の反複：sigma= 0.2111, Objval= 6.7764
# 81回目の反複：sigma= 0.1987, Objval= 6.7889
# 82回目の反複：sigma= 0.2475, Objval= 6.7950
# 83回目の反複：sigma= 0.2355, Objval= 6.7525
# 84回目の反複：sigma= 0.2236, Objval= 6.7645
# 85回目の反複：sigma= 0.2118, Objval= 6.7764
# 86回目の反複：sigma= 0.2002, Objval= 6.7882
# 87回目の反複：sigma= 0.1887, Objval= 6.7998
# 88回目の反複：sigma= 0.2341, Objval= 6.7548
# 89回目の反複：sigma= 0.2229, Objval= 6.7659
# 90回目の反複：sigma= 0.2118, Objval= 6.7771
# 91回目の反複：sigma= 0.2008, Objval= 6.7882
# 92回目の反複：sigma= 0.1899, Objval= 6.7992
# 93回目の反複：sigma= 0.2329, Objval= 6.7598
# 94回目の反複：sigma= 0.2223, Objval= 6.7671
# 95回目の反複：sigma= 0.2118, Objval= 6.7777
# 96回目の反複：sigma= 0.2014, Objval= 6.7882
# 97回目の反複：sigma= 0.1911, Objval= 6.7986
# 98回目の反複：sigma= 0.2319, Objval= 6.7642
# 99回目の反複：sigma= 0.2218, Objval= 6.7681
# 100回目の反複：sigma= 0.2118, Objval= 6.7782
# 101回目の反複：sigma= 0.2118, Objval= 6.7882

# %% [markdown]
# 最終的に得られた解

# %%
# 最適化
model = solve_LSP(V, E, u, sigma=sigma)
model.optimize()
print(f'Optimal Value: {model.ObjVal}')

x = model.__data
eps = 1.0e-6
optsol = []
for i, j in x:
    if x[i, j].X > eps:
        optsol.append(x[i, j])

print(f'Optimal Solution: {optsol}')
# Out:
# Optimal Value: 6.788226890923063
# Optimal Solution: [x_0,1, x_1,3]

# %% [markdown]
# ## 等式制約に対するラグランジュ緩和問題 (LKNAP)

# %%
# CSPを解いた結果を返す関数
def solve_LKNAP(V, E, u, lambda_):
    model = Model('lknap')
    
    ## 変数
    x = {}
    for i, j in E:
        x[i, j] = model.addVar(vtype='B', name=f'x_{i},{j}')
    model.update()
    
    ## 定式化
    ### 制約式
    model.addConstr(quicksum(c[i, j] * x[i, j] for i, j in E) <= u)
 
    ### 目的関数
    model.setObjective(quicksum(l[i, j] * x[i, j] for i, j in E)
                       + lambda_[0] * (1 - quicksum(x[i, j] for i, j in E if i==V[0]))
                       + lambda_[1] * (-1 + quicksum(x[i, j] for i, j in E if j==V[-1]))
                       + quicksum(
                           lambda_[k] * (-quicksum(x[i_, j] for i_, j in [(i_, j) for i_, j in E if i_==i])
                                         + quicksum(x[i_, j] for i_, j in [(j, i_) for j, i_ in E if i_==i])
                                        )
                           for k, i in enumerate(V[1: -1], 2)),
                       GRB.MINIMIZE)
    
    model.update()
    model.__data = x
    
    return model

# %%
lambda_ = [0, 0, 0, 0]
count = 1
eps = 1.0e-3
converge = False

while not converge:
    # LKNAPを解く
    model = solve_LKNAP(V, E, u, lambda_=lambda_)
    model.optimize()
    x = model.__data
    
    # 劣勾配
    sub_grad = [
        1 - value(quicksum(x[i, j].X for i, j in E if i==V[0])),
        -1 + value(quicksum(x[i, j].X for i, j in E if j==V[-1]))
    ]
    for i in V[1: -1]:
        sub_grad.append(
            value(
                -quicksum(x[i_, j].X for i_, j in [(i_, j) for i_, j in E if i_==i])
                + quicksum(x[i_, j].X for i_, j in [(j, i_) for j, i_ in E if i_==i])
            )
        )
    
    # ちゃんと収束するようにlambdaの更新幅は徐々に小さくしていく
    # lambdaの更新幅が微小定数epsよりも小さくなれば終了する
    if np.max(np.abs(sub_grad)) / count < eps:
        converge = True
        count += 1
    else:
        lambda_ = [lambda_[i] + sub_grad[i] / count for i in range(len(sub_grad))]
        count += 1

    print(f'{count-1}回目の反複： Objval={model.ObjVal: .4f}')
print(f'lambda={lambda_}')
# Out:
# 1回目の反複： Objval= 0.0000
# 2回目の反複： Objval= 2.0000
# 3回目の反複： Objval= 3.0000
# 4回目の反複： Objval= 3.6667
# 5回目の反複： Objval= 4.0833
# 6回目の反複： Objval= 4.3667
# 7回目の反複： Objval= 4.6500
# 8回目の反複： Objval= 4.8429
# 9回目の反複： Objval= 5.0607
# 10回目の反複： Objval= 5.2040
# 11回目の反複： Objval= 5.3829
# 12回目の反複： Objval= 5.4750
# 13回目の反複： Objval= 5.5648
# 14回目の反複： Objval= 5.6417
# 15回目の反複： Objval= 5.7186
# 16回目の反複： Objval= 5.7845
# 17回目の反複： Objval= 5.8519
# 18回目の反複： Objval= 5.9095
# 19回目の反複： Objval= 5.9495
# 20回目の反複： Objval= 5.9675
# 21回目の反複： Objval= 5.9553
# 22回目の反複： Objval= 5.9722
# 23回目の反複： Objval= 6.0545
# 24回目の反複： Objval= 6.0197
# 25回目の反複： Objval= 6.0585
# 26回目の反複： Objval= 6.0230
# 27回目の反複： Objval= 6.0999
# 28回目の反複： Objval= 6.0675
# 29回目の反複： Objval= 6.1026
# 30回目の反複： Objval= 6.1413
# 31回目の反複： Objval= 6.1382
# 32回目の反複： Objval= 6.1435
# 33回目の反複： Objval= 6.1402
# 34回目の反複： Objval= 6.2008
# 35回目の反複： Objval= 6.1491
# 36回目の反複： Objval= 6.2025
# 37回目の反複： Objval= 6.2078
# 38回目の反複： Objval= 6.2040
# 39回目の反複： Objval= 6.2356
# 40回目の反複： Objval= 6.2310
# 41回目の反複： Objval= 6.2618
# 42回目の反複： Objval= 6.2566
# 43回目の反複： Objval= 6.2657
# 44回目の反複： Objval= 6.2577
# 45回目の反複： Objval= 6.3032
# 46回目の反複： Objval= 6.2688
# 47回目の反複： Objval= 6.3041
# 48回目の反複： Objval= 6.3106
# 49回目の反複： Objval= 6.3259
# 50回目の反複： Objval= 6.3141
# 51回目の反複： Objval= 6.3267
# 52回目の反複： Objval= 6.3522
# 53回目の反複： Objval= 6.3467
# 54回目の反複： Objval= 6.3556
# 55回目の反複： Objval= 6.3474
# 56回目の反複： Objval= 6.3837
# 57回目の反複： Objval= 6.3576
# 58回目の反複： Objval= 6.3843
# 59回目の反複： Objval= 6.3907
# 60回目の反複： Objval= 6.4019
# 61回目の反複： Objval= 6.3939
# 62回目の反複： Objval= 6.4024
# 63回目の反複： Objval= 6.4245
# 64回目の反複： Objval= 6.4188
# 65回目の反複： Objval= 6.4277
# 66回目の反複： Objval= 6.4193
# 67回目の反複： Objval= 6.4496
# 68回目の反複： Objval= 6.4291
# 69回目の反複： Objval= 6.4500
# 70回目の反複： Objval= 6.4563
# 71回目の反複： Objval= 6.4647
# 72回目の反複： Objval= 6.4593
# 73回目の反複： Objval= 6.4651
# 74回目の反複： Objval= 6.4848
# 75回目の反複： Objval= 6.4790
# 76回目の反複： Objval= 6.4878
# 77回目の反複： Objval= 6.4794
# 78回目の反複： Objval= 6.5053
# 79回目の反複： Objval= 6.4888
# 80回目の反複： Objval= 6.5057
# 81回目の反複： Objval= 6.5119
# 82回目の反複： Objval= 6.5183
# 83回目の反複： Objval= 6.5148
# 84回目の反複： Objval= 6.5186
# 85回目の反複： Objval= 6.5366
# 86回目の反複： Objval= 6.5307
# 87回目の反複： Objval= 6.5394
# 88回目の反複： Objval= 6.5309
# 89回目の反複： Objval= 6.5536
# 90回目の反複： Objval= 6.5402
# 91回目の反複： Objval= 6.5539
# 92回目の反複： Objval= 6.5601
# 93回目の反複： Objval= 6.5650
# 94回目の反複： Objval= 6.5629
# 95回目の反複： Objval= 6.5652
# 96回目の反複： Objval= 6.5818
# 97回目の反複： Objval= 6.5759
# 98回目の反複： Objval= 6.5846
# 99回目の反複： Objval= 6.5761
# 100回目の反複： Objval= 6.5963
# 101回目の反複： Objval= 6.5852
# 102回目の反複： Objval= 6.5965
# 103回目の反複： Objval= 6.6026
# 104回目の反複： Objval= 6.6064
# 105回目の反複： Objval= 6.6054
# 106回目の反複： Objval= 6.6066
# 107回目の反複： Objval= 6.6221
# 108回目の反複： Objval= 6.6161
# 109回目の反複： Objval= 6.6248
# 110回目の反複： Objval= 6.6163
# 111回目の反複： Objval= 6.6344
# 112回目の反複： Objval= 6.6253
# 113回目の反複： Objval= 6.6346
# 114回目の反複： Objval= 6.6407
# 115回目の反複： Objval= 6.6435
# 116回目の反複： Objval= 6.6435
# 117回目の反複： Objval= 6.6437
# 118回目の反複： Objval= 6.6583
# 119回目の反複： Objval= 6.6523
# 120回目の反複： Objval= 6.6610
# 121回目の反複： Objval= 6.6524
# 122回目の反複： Objval= 6.6690
# 123回目の反複： Objval= 6.6614
# 124回目の反複： Objval= 6.6691
# 125回目の反複： Objval= 6.6752
# 126回目の反複： Objval= 6.6772
# 127回目の反複： Objval= 6.6779
# 128回目の反複： Objval= 6.6773
# 129回目の反複： Objval= 6.6912
# 130回目の反複： Objval= 6.6852
# 131回目の反複： Objval= 6.6939
# 132回目の反複： Objval= 6.6853
# 133回目の反複： Objval= 6.7005
# 134回目の反複： Objval= 6.6943
# 135回目の反複： Objval= 6.7006
# 136回目の反複： Objval= 6.7067
# 137回目の反複： Objval= 6.7081
# 138回目の反複： Objval= 6.7094
# 139回目の反複： Objval= 6.7082
# 140回目の反複： Objval= 6.7214
# 141回目の反複： Objval= 6.7154
# 142回目の反複： Objval= 6.7241
# 143回目の反複： Objval= 6.7155
# 144回目の反複： Objval= 6.7295
# 145回目の反複： Objval= 6.7244
# 146回目の反複： Objval= 6.7296
# 147回目の反複： Objval= 6.7357
# 148回目の反複： Objval= 6.7365
# 149回目の反複： Objval= 6.7384
# 150回目の反複： Objval= 6.7366
# 151回目の反複： Objval= 6.7493
# 152回目の反複： Objval= 6.7433
# 153回目の反複： Objval= 6.7520
# 154回目の反複： Objval= 6.7434
# 155回目の反複： Objval= 6.7564
# 156回目の反複： Objval= 6.7522
# 157回目の反複： Objval= 6.7565
# 158回目の反複： Objval= 6.7626
# 159回目の反複： Objval= 6.7629
# 160回目の反複： Objval= 6.7652
# 161回目の反複： Objval= 6.7629
# 162回目の反複： Objval= 6.7752
# 163回目の反複： Objval= 6.7692
# 164回目の反複： Objval= 6.7779
# 165回目の反複： Objval= 6.7693
# 166回目の反複： Objval= 6.7814
# 167回目の反複： Objval= 6.7781
# 168回目の反複： Objval= 6.7815
# 169回目の反複： Objval= 6.7876
# 170回目の反複： Objval= 6.7874
# 171回目の反複： Objval= 6.7902
# 172回目の反複： Objval= 6.7875
# 173回目の反複： Objval= 6.7991
# 174回目の反複： Objval= 6.7904
# 175回目の反複： Objval= 6.7992
# 176回目の反複： Objval= 6.7994
# 177回目の反複： Objval= 6.8050
# 178回目の反複： Objval= 6.8020
# 179回目の反複： Objval= 6.8050
# 180回目の反複： Objval= 6.8108
# 181回目の反複： Objval= 6.8106
# 182回目の反複： Objval= 6.8134
# 183回目の反複： Objval= 6.8107
# 184回目の反複： Objval= 6.8216
# 185回目の反複： Objval= 6.8136
# 186回目の反複： Objval= 6.8217
# 187回目の反複： Objval= 6.8219
# 188回目の反複： Objval= 6.8271
# 189回目の反複： Objval= 6.8245
# 190回目の反複： Objval= 6.8271
# 191回目の反複： Objval= 6.8326
# 192回目の反複： Objval= 6.8324
# 193回目の反複： Objval= 6.8352
# 194回目の反複： Objval= 6.8325
# 195回目の反複： Objval= 6.8428
# 196回目の反複： Objval= 6.8354
# 197回目の反複： Objval= 6.8429
# 198回目の反複： Objval= 6.8431
# 199回目の反複： Objval= 6.8480
# 200回目の反複： Objval= 6.8457
# 201回目の反複： Objval= 6.8480
# 202回目の反複： Objval= 6.8532
# 203回目の反複： Objval= 6.8530
# 204回目の反複： Objval= 6.8558
# 205回目の反複： Objval= 6.8531
# 206回目の反複： Objval= 6.8628
# 207回目の反複： Objval= 6.8559
# 208回目の反複： Objval= 6.8629
# 209回目の反複： Objval= 6.8631
# 210回目の反複： Objval= 6.8677
# 211回目の反複： Objval= 6.8657
# 212回目の反複： Objval= 6.8677
# 213回目の反複： Objval= 6.8726
# 214回目の反複： Objval= 6.8725
# 215回目の反複： Objval= 6.8752
# 216回目の反複： Objval= 6.8725
# 217回目の反複： Objval= 6.8818
# 218回目の反複： Objval= 6.8754
# 219回目の反複： Objval= 6.8818
# 220回目の反複： Objval= 6.8820
# 221回目の反複： Objval= 6.8864
# 222回目の反複： Objval= 6.8846
# 223回目の反複： Objval= 6.8864
# 224回目の反複： Objval= 6.8911
# 225回目の反複： Objval= 6.8909
# 226回目の反複： Objval= 6.8937
# 227回目の反複： Objval= 6.8910
# 228回目の反複： Objval= 6.8998
# 229回目の反複： Objval= 6.8938
# 230回目の反複： Objval= 6.8998
# 231回目の反複： Objval= 6.9000
# 232回目の反複： Objval= 6.9042
# 233回目の反複： Objval= 6.9026
# 234回目の反複： Objval= 6.9042
# 235回目の反複： Objval= 6.9087
# 236回目の反複： Objval= 6.9085
# 237回目の反複： Objval= 6.9113
# 238回目の反複： Objval= 6.9086
# 239回目の反複： Objval= 6.9170
# 240回目の反複： Objval= 6.9114
# 241回目の反複： Objval= 6.9170
# 242回目の反複： Objval= 6.9172
# 243回目の反複： Objval= 6.9212
# 244回目の反複： Objval= 6.9198
# 245回目の反複： Objval= 6.9212
# 246回目の反複： Objval= 6.9255
# 247回目の反複： Objval= 6.9253
# 248回目の反複： Objval= 6.9281
# 249回目の反複： Objval= 6.9253
# 250回目の反複： Objval= 6.9334
# 251回目の反複： Objval= 6.9282
# 252回目の反複： Objval= 6.9334
# 253回目の反複： Objval= 6.9336
# 254回目の反複： Objval= 6.9374
# 255回目の反複： Objval= 6.9362
# 256回目の反複： Objval= 6.9374
# 257回目の反複： Objval= 6.9415
# 258回目の反複： Objval= 6.9413
# 259回目の反複： Objval= 6.9441
# 260回目の反複： Objval= 6.9414
# 261回目の反複： Objval= 6.9491
# 262回目の反複： Objval= 6.9442
# 263回目の反複： Objval= 6.9491
# 264回目の反複： Objval= 6.9493
# 265回目の反複： Objval= 6.9529
# 266回目の反複： Objval= 6.9519
# 267回目の反複： Objval= 6.9529
# 268回目の反複： Objval= 6.9569
# 269回目の反複： Objval= 6.9567
# 270回目の反複： Objval= 6.9594
# 271回目の反複： Objval= 6.9567
# 272回目の反複： Objval= 6.9641
# 273回目の反複： Objval= 6.9595
# 274回目の反複： Objval= 6.9641
# 275回目の反複： Objval= 6.9643
# 276回目の反複： Objval= 6.9678
# 277回目の反複： Objval= 6.9669
# 278回目の反複： Objval= 6.9678
# 279回目の反複： Objval= 6.9716
# 280回目の反複： Objval= 6.9714
# 281回目の反複： Objval= 6.9742
# 282回目の反複： Objval= 6.9715
# 283回目の反複： Objval= 6.9785
# 284回目の反複： Objval= 6.9743
# 285回目の反複： Objval= 6.9786
# 286回目の反複： Objval= 6.9788
# 287回目の反複： Objval= 6.9821
# 288回目の反複： Objval= 6.9813
# 289回目の反複： Objval= 6.9821
# 290回目の反複： Objval= 6.9858
# 291回目の反複： Objval= 6.9856
# 292回目の反複： Objval= 6.9883
# 293回目の反複： Objval= 6.9856
# 294回目の反複： Objval= 6.9924
# 295回目の反複： Objval= 6.9884
# 296回目の反複： Objval= 6.9925
# 297回目の反複： Objval= 6.9926
# 298回目の反複： Objval= 6.9958
# 299回目の反複： Objval= 6.9952
# 300回目の反複： Objval= 6.9959
# 301回目の反複： Objval= 6.9994
# 302回目の反複： Objval= 6.9992
# 303回目の反複： Objval= 6.9993
# 304回目の反複： Objval= 7.0000
# lambda=[3.5063354604902828, -4.5047678784617515, 1.5004846766406812, -0.5020522586692115]

# %% [markdown]
# 最終的に得られた解

# %%
# 最適化
model = solve_LKNAP(V, E, u, lambda_=lambda_)
model.optimize()
print(f'Optimal Value: {model.ObjVal}')

x = model.__data
eps = 1.0e-6
optsol = []
for i, j in x:
    if x[i, j].X > eps:
        optsol.append(x[i, j])

print(f'Optimal Solution: {optsol}')
# Out:
# Optimal Value: 7.000000000000001
# Optimal Solution: [x_0,1, x_1,3]
